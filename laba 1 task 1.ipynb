# %%
#Завантаження даних iris-dataset
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
print(iris.DESCR)
print(iris.feature_names)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
print(iris.data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
#Перемішати записи у завантаженій базі 
from sklearn.datasets import load_iris
import numpy as np

iris = load_iris()

indices = np.arange(len(iris.target))
np.random.shuffle(indices)
X = iris.data[indices]
y = iris.target[indices]

print(X)
print(y)
# Out:
# [[5.1 3.8 1.9 0.4]
#  [6.7 3.3 5.7 2.1]
#  [5.4 3.9 1.7 0.4]
#  [6.  3.4 4.5 1.6]
#  [4.9 3.1 1.5 0.1]
#  [6.7 2.5 5.8 1.8]
#  [5.7 2.5 5.  2. ]
#  [5.7 2.8 4.5 1.3]
#  [6.5 3.  5.5 1.8]
#  [5.  2.  3.5 1. ]
#  [7.4 2.8 6.1 1.9]
#  [5.  3.4 1.6 0.4]
#  [5.  2.3 3.3 1. ]
#  [4.7 3.2 1.3 0.2]
#  [5.2 3.4 1.4 0.2]
#  [5.7 3.  4.2 1.2]
#  [7.2 3.2 6.  1.8]
#  [6.7 3.1 4.7 1.5]
#  [5.1 2.5 3.  1.1]
#  [6.  2.9 4.5 1.5]
#  [6.3 2.5 5.  1.9]
#  [6.2 2.8 4.8 1.8]
#  [5.8 2.7 4.1 1. ]
#  [7.3 2.9 6.3 1.8]
#  [5.1 3.7 1.5 0.4]
#  [5.  3.3 1.4 0.2]
#  [5.5 2.4 3.7 1. ]
#  [5.7 4.4 1.5 0.4]
#  [7.7 3.  6.1 2.3]
#  [6.5 3.2 5.1 2. ]
#  [7.2 3.6 6.1 2.5]
#  [7.7 2.6 6.9 2.3]
#  [6.4 3.1 5.5 1.8]
#  [6.1 2.9 4.7 1.4]
#  [4.8 3.  1.4 0.3]
#  [6.  2.2 5.  1.5]
#  [4.9 2.4 3.3 1. ]
#  [6.  2.7 5.1 1.6]
#  [4.4 3.  1.3 0.2]
#  [6.3 2.3 4.4 1.3]
#  [6.1 2.8 4.7 1.2]
#  [6.9 3.2 5.7 2.3]
#  [5.2 4.1 1.5 0.1]
#  [5.7 2.9 4.2 1.3]
#  [5.8 2.7 5.1 1.9]
#  [6.6 2.9 4.6 1.3]
#  [5.6 2.7 4.2 1.3]
# ...

# %%
#Нормалізувати параметри квітів ірису
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler

iris = load_iris()
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(iris.data)
print(X_normalized)
# Out:
# [[0.22222222 0.625      0.06779661 0.04166667]
#  [0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.11111111 0.5        0.05084746 0.04166667]
#  [0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.02777778 0.375      0.06779661 0.04166667]
#  [0.16666667 0.45833333 0.08474576 0.        ]
#  [0.30555556 0.70833333 0.08474576 0.04166667]
#  [0.13888889 0.58333333 0.10169492 0.04166667]
#  [0.13888889 0.41666667 0.06779661 0.        ]
#  [0.         0.41666667 0.01694915 0.        ]
#  [0.41666667 0.83333333 0.03389831 0.04166667]
#  [0.38888889 1.         0.08474576 0.125     ]
#  [0.30555556 0.79166667 0.05084746 0.125     ]
#  [0.22222222 0.625      0.06779661 0.08333333]
#  [0.38888889 0.75       0.11864407 0.08333333]
#  [0.22222222 0.75       0.08474576 0.08333333]
# ...

# %%
# Розділити існуючі записи на навчальну і тестові вибірки 
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)
print("Розмір навчальної вибірки:", X_train.shape)
print("Розмір тестової вибірки:", X_test.shape)
# Out:
# Розмір навчальної вибірки: (120, 4)
# Розмір тестової вибірки: (30, 4)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def generate_regression_data(num_samples):
    X = np.random.uniform(low=-10, high=10, size=num_samples)
    noise = np.random.normal(scale=2, size=num_samples)
    y = 2 * X + 5 + noise
    return X, y
X, y = generate_regression_data(num_samples=100)
plt.scatter(X, y)
plt.show()

# %%
#Навчити KNN-класифікатор з різними значеннями K 
from sklearn.neighbors import KNeighborsClassifier
k_values = [1, 3, 5, 7, 9]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    
    knn.fit(X_train, y_train)   
    accuracy = knn.score(X_test, y_test)
    print("Accuracy for k = {}: {}".format(k, accuracy))
# Out:
# Accuracy for k = 1: 1.0
# Accuracy for k = 3: 1.0
# Accuracy for k = 5: 1.0
# Accuracy for k = 7: 0.9666666666666667
# Accuracy for k = 9: 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

X, y = make_regression(n_samples=1000, n_features=10, random_state=42)

scaler = StandardScaler()
X_norm = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=42)

k_list = [1, 3, 5, 7, 9]

mse_scores = []

for k in k_list:
    knn = KNeighborsRegressor(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)
    print("MSE score for k={}: {}".format(k, mse))

best_k = k_list[mse_scores.index(min(mse_scores))]
print("Best k by MSE score: {}".format(best_k))

plt.plot(k_list, mse_scores)
plt.xlabel('K')
plt.ylabel('MSE')
plt.title('MSE vs K')
plt.show()
# Out:
# MSE score for k=1: 7095.476438539933
# MSE score for k=3: 4440.01023674447
# MSE score for k=5: 3893.3184542725066
# MSE score for k=7: 3835.5781063125096
# MSE score for k=9: 3964.2844777326773
# Best k by MSE score: 7
